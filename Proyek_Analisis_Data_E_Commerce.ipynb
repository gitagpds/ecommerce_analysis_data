# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Gita Poetri Dewi Siregar
# - **Email:** gitapoetrisiregar@gmail.com
# - **ID Dicoding:** gitagpds

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?
#
# - Produk apa yang paling banyak dan paling sedikit terjual?
#
# - Bagaimana demografi pelanggan yang melakukan pembelian?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %% [markdown]
# Pada tahap ini yang dilakukan adalah mengimpor semua pustaka yang diperlukan untuk analisis data, meliput numpy dan pandas untuk analisis data serta matplotlib dan seaborn untuk visualisasi data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Pada tahap ini yang dilakukan adalah mengumpulkan data yang akan dianalisis. Data berasal dari file CSV customer_dataset, orders_dataset, order_items_dataset, dan products_dataset. Dalam hal ini, library **pandas** digunakan untuk membaca dataset dari file CSV dan menyimpannya dalam bentuk DataFrame agar lebih mudah diproses dan dianalisis.

# %% [markdown]
# **Memuat Tabel customer_dataset**

# %%
# Membaca file CSV "customers_dataset.csv" dan menyimpannya ke dalam DataFrame bernama customers_df
customers_df = pd.read_csv("/content/drive/MyDrive/Dataset/customers_dataset.csv")

# Menampilkan lima baris pertama dari DataFrame customers_df untuk memberikan gambaran awal tentang struktur dan isi data
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **Memuat Tabel orders_dataset**

# %%
# Membaca file CSV "orders_dataset.csv" dan menyimpannya ke dalam DataFrame bernama orders_df
orders_df = pd.read_csv("/content/drive/MyDrive/Dataset/orders_dataset.csv")

# Menampilkan lima baris pertama dari DataFrame orders_df untuk memberikan gambaran awal tentang struktur dan isi data
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **Memuat Tabel order_items_dataset**

# %%
# Membaca file CSV "order_items_dataset.csv" dan menyimpannya ke dalam DataFrame bernama order_items_df
order_items_df = pd.read_csv("/content/drive/MyDrive/Dataset/order_items_dataset.csv")

# Menampilkan lima baris pertama dari DataFrame order_items_df untuk memberikan gambaran awal tentang struktur dan isi data
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **Memuat Tabel products_dataset**

# %%
# Membaca file CSV "products_dataset.csv" dan menyimpannya ke dalam DataFrame bernama products_df
products_df = pd.read_csv("/content/drive/MyDrive/Dataset/products_dataset.csv")

# Menampilkan lima baris pertama dari DataFrame products_df untuk memberikan gambaran awal tentang struktur dan isi data
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Pada tahap ini yang dilakukan adalah mengidentifikasi masalah yang terdapat dalam data dan memastikan data tersebut berkualitas.

# %% [markdown]
# **Menilai Tabel customer_dataset**

# %%
# Menampilkan informasi detail tentang DataFrame customers_df
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# Tidak ada masalah mengenai tipe data pada masing-masing kolom yang ada. Jumlah seluruh data dan jumlah data masing-masing kolom juga sesuai, jadi tidak ada missing value.

# %%
# Menghitung jumlah missing value di setiap kolom dalam DataFrame customers_df
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# Dibuktikan bahwa semua kolom tidak ada yang mempunyai missing value.

# %%
# Menampilkan jumlah baris duplikat dalam DataFrame customers_df
print("Jumlah duplikasi: ", customers_df.duplicated().sum())

# Menampilkan statistik deskriptif untuk data numerik di customers_df
customers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# Tidak ada duplikasi data dan pada ringkasan parameter statistik juga tidak menimbulkan keanehan nilai yang berarti.

# %% [markdown]
# **KESIMPULAN ASSESSING DATA TABEL customer_dataset**
#
# 1. Tipe Data : Tidak ada kesalahan tipe data.
# 2. Missing Value : Tidak ada missing value.
# 3. Duplicate Data : Tidak ada duplikasi data.
# 4. Inaccurate value : Tidak ada keanehan nilai.

# %% [markdown]
# **Menilai Tabel orders_dataset**

# %%
# Menampilkan informasi detail tentang DataFrame orders_df
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# - Terlihat ada beberapa kolom yang jumlah datanya tidak sesuai dengan jumlah seluruh data yang mengindikasikan adanya missing value.
# - Terdapat kesalahan tipe data untuk kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, dan order_estimated_delivery_date. Kelima kolom tersebut harusnya direpresentasikan sebagai tipe data **datetime**, bukan **object** (tipe data string).

# %%
# Menghitung jumlah missing value di setiap kolom dalam DataFrame orders_df
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Missing value terdapat pada 3 kolom yaitu :
# - order_approved_at = 160 missing value
# - order_delivered_carrier_date = 1783 missing value
# - order_delivered_customer_date = 2965 missing value

# %%
# Menampilkan jumlah baris duplikat dalam DataFrame orders_df
print("Jumlah duplikasi: ", orders_df.duplicated().sum())

# Menampilkan statistik deskriptif untuk data numerik di orders_df
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# Tidak ada indikasi duplikasi data.

# %% [markdown]
# **KESIMPULAN ASSESSING DATA TABEL orders_dataset**
#
# 1. Tipe Data : Terdapat kesalahan tipe data pada 5 kolom.
# 2. Missing Value : Terdapat missing value pada 3 kolom.
# 3. Duplicate Data : Tidak ada duplikasi data.
# 4. Inaccurate value : Tidak ada keanehan nilai.

# %% [markdown]
# ****Menilai Tabel order_items_dataset****

# %%
# Menampilkan informasi detail tentang DataFrame order_items_df
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# - Jumlah seluruh data dan jumlah data masing-masing kolom sesuai, jadi tidak ada missing value.
# - Terdapat kesalahan tipe data untuk kolom shipping_limit_date. Kolom tersebut harusnya direpresentasikan sebagai tipe data datetime, bukan object (tipe data string).

# %%
# Menghitung jumlah missing value di setiap kolom dalam DataFrame order_items_df
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# Dibuktikan bahwa semua kolom tidak ada yang mempunyai missing value.

# %%
# Menampilkan jumlah baris duplikat dalam DataFrame order_items_df
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())

# Menampilkan statistik deskriptif untuk data numerik di order_items_df
order_items_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# Tidak ada duplikasi data dan pada ringkasan parameter statistik juga tidak menimbulkan keanehan nilai yang berarti.

# %% [markdown]
# **KESIMPULAN ASSESSING DATA TABEL order_items_dataset**
#
# 1. Tipe Data : Terdapat kesalahan tipe data pada kolom shipping_limit_date.
# 2. Missing Value : Tidak ada missing value.
# 3. Duplicate Data : Tidak ada duplikasi data.
# 4. Inaccurate value : Tidak ada keanehan nilai.

# %% [markdown]
# **Menilai Tabel products_dataset**

# %%
# Menampilkan informasi detail tentang DataFrame products_df
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# - Terlihat ada beberapa kolom yang jumlah datanya tidak sesuai dengan jumlah seluruh data yang mengindikasikan adanya missing value.
# - Terdapat kesalahan tipe data untuk kolom product_photos_qty. Kolom tersebut harusnya direpresentasikan sebagai tipe data integer, bukan float.

# %%
# Menghitung jumlah missing value di setiap kolom dalam DataFrame products_df
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Missing value terdapat pada 8 kolom yaitu :
# - product_category_name = 610 missing value
# - product_name_lenght = 610 missing value
# - product_description_lenght = 610 missing value
# - product_photos_qty = 610 missing value
# - product_weight_g = 2 missing value
# - product_length_cm	= 2 missing value
# - product_height_cm = 2 missing value
# - product_width_cm = 2 missing value

# %%
# Menampilkan jumlah baris duplikat dalam DataFrame products_df
print("Jumlah duplikasi: ", products_df.duplicated().sum())

# Menampilkan statistik deskriptif untuk data numerik di products_df
products_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# - Tidak ada duplikasi data.
# - Terdapat inaccurate value pada kolom product_weight_g. Nilai minimum berat sebuah benda tidak mungkin 0 gram karena minimum sebuah benda memiliki berat yang pasti > 0 gram.

# %% [markdown]
# **KESIMPULAN ASSESSING DATA TABEL products_dataset**
#
# 1. Tipe Data : Terdapat kesalahan tipe data pada kolom product_photos_qty.
# 2. Missing Value : Terdapat missing value pada 8 kolom.
# 3. Duplicate Data : Tidak ada duplikasi data.
# 4. Inaccurate value : Terdapat inaccurate value pada kolom product_weight_g.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Pada tahap ini yang dilakukan adalah membersihkan data dengan mengatasi missing values, kesalahan tipe data, menghapus data duplikat, serta menangani nilai-nilai yang tidak sesuai atau outlier. Hal ini dilakukan agar data siap untuk dianalisis lebih lanjut dan memastikan hasil analisis yang akurat.

# %% [markdown]
# **Membersihkan Data customers_df**

# %% [markdown]
# **KESIMPULAN ASSESSING DATA TABEL customer_dataset**
#
# 1. Tipe Data : Tidak ada kesalahan tipe data.
# 2. Missing Value : Tidak ada missing value.
# 3. Duplicate Data : Tidak ada duplikasi data.
# 4. Inaccurate value : Tidak ada keanehan nilai.

# %% [markdown]
# Berdasarkan kesimpulan Assessing Data pada tabel customer_dataset, maka data customer_dataset tidak perlu dibersihkan.

# %% [markdown]
# **Membersihkan Data orders_dataset**

# %% [markdown]
# **KESIMPULAN ASSESSING DATA TABEL orders_dataset**
#
# 1. Tipe Data : Terdapat kesalahan tipe data pada 5 kolom.
# 2. Missing Value : Terdapat missing value pada 3 kolom.
# 3. Duplicate Data : Tidak ada duplikasi data.
# 4. Inaccurate value : Tidak ada keanehan nilai.

# %% [markdown]
# Berdasarkan hasil proses assessing data, diketahui bahwa terdapat dua masalah yang dijumpai dalam orders_df, yaitu kesalahan tipe data dan missing value. Pada tahap ini, akan dilakukan pembersihan kedua masalah tersebut.

# %% [markdown]
# > **- Menangani kesalahan tipe data**

# %%
# Mendefinisikan kolom-kolom yang ingin dikonversi ke tipe datetime
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

# Mengonversi setiap kolom di 'datetime_columns' menjadi format datetime menggunakan pd.to_datetime
for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
# Menampilkan informasi detail tentang DataFrame orders_df kembali agar memastikan bahwa tipe data telah berubah
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# > **- Menangani missing value**

# %%
# Menampilkan baris-baris dari DataFrame 'orders_df' yang kolom 'order_approved_at'-nya memiliki missing value
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
# Menampilkan baris-baris dari DataFrame 'orders_df' yang kolom 'order_delivered_carrier_date'-nya memiliki missing value
orders_df[orders_df.order_delivered_carrier_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
# Menampilkan baris-baris dari DataFrame 'orders_df' yang kolom 'order_delivered_customer_date'-nya memiliki missing value
orders_df[orders_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# Akan dilakukan **drop** pada baris-baris data yang memiliki missing value. **Drop** dipakai karena jumlah data yang akan hilang setelah di**drop** masih bisa ditoleransi yaitu kurang lebih 3%. Alasan lain adalah jika dilakukan **imputation** maka bisa menyebabkan bias dan mengganti tanggal dengan nilai estimasi mungkin dapat merusak integritas kronologi data.

# %%
# Drop hanya jika ada missing value pada kolom tertentu dan simpan hasilnya ke orders_df
orders_df.dropna(subset=['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'], inplace=True)

# Mengecek apakah missing value masih ada
print(orders_df.isna().sum())
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# Setelah dilakukan **drop** maka tidak ada lagi data yang memiliki missing value

# %%
# Menampilkan informasi detail tentang DataFrame orders_df kembali untuk memastikan bahwa setiap masalah telah teratasi
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  datetime64[ns]
#  4   order_approved_at              96461 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96461 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96461 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.6+ MB

# %% [markdown]
# Semula jumlah datanya adalah 99441 dan setelah dilakukan **drop**, jumlah data yang tersisa masih 96461. Data ini masih cukup besar untuk dilakukan analisis data dan jumlah data yang hilang hanya sekitar 3%:

# %% [markdown]
# **Membersihkan Data order_items_dataset**

# %% [markdown]
# **KESIMPULAN ASSESSING DATA TABEL order_items_dataset**
#
# 1. Tipe Data : Terdapat kesalahan tipe data pada kolom shipping_limit_date.
# 2. Missing Value : Tidak ada missing value.
# 3. Duplicate Data : Tidak ada duplikasi data.
# 4. Inaccurate value : Tidak ada keanehan nilai.

# %% [markdown]
# Berdasarkan hasil proses assessing data, diketahui bahwa terdapat satu masalah yang dijumpai dalam order_items_df, yaitu kesalahan tipe data. Pada tahap ini, akan dilakukan pembersihan pada masalah tersebut.

# %% [markdown]
# > **- Menangani kesalahan tipe data**

# %%
# Mendefinisikan kolom yang ingin dikonversi ke tipe datetime
datetime_columns = ["shipping_limit_date"]

# Mengonversi kolom di 'datetime_columns' menjadi format datetime menggunakan pd.to_datetime
for column in datetime_columns:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
# Menampilkan informasi detail tentang DataFrame order_items_df kembali untuk memastikan tipe data shipping_limit_date telah berubah
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# **Membersihkan Data products_dataset**

# %% [markdown]
# **KESIMPULAN ASSESSING DATA TABEL products_dataset**
#
# 1. Tipe Data : Terdapat kesalahan tipe data pada kolom product_photos_qty.
# 2. Missing Value : Terdapat missing value pada 8 kolom.
# 3. Duplicate Data : Tidak ada duplikasi data.
# 4. Inaccurate value : Terdapat inaccurate value pada kolom product_weight_g.

# %% [markdown]
# Berdasarkan hasil proses assessing data, diketahui bahwa terdapat tiga masalah yang dijumpai dalam products_df, yaitu kesalahan tipe data, missing value, dan inaccurate value. Pada tahap ini, akan dilakukan pembersihan ketiga masalah tersebut.

# %% [markdown]
# > **- Menangani missing value**

# %%
# Menampilkan baris-baris dari DataFrame 'products_df' yang kolom 'product_category_name'-nya memiliki missing value
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
# Cek jumlah baris yang memiliki missing value di ke-8 kolom secara bersamaan
missing_8_cols = products_df[products_df[['product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']].isna().all(axis=1)]

# Menampilkan jumlah baris yang memiliki missing value di ke-8 kolom
print(f"Jumlah baris dengan missing value di semua 8 kolom: {len(missing_8_cols)}")
# Out:
# Jumlah baris dengan missing value di semua 8 kolom: 1

# %%
# Cek jumlah baris yang memiliki missing value di ke-4 kolom secara bersamaan
missing_4_cols = products_df[products_df[['product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty']].isna().all(axis=1)]

# Menampilkan jumlah baris yang memiliki missing value di ke-4 kolom
print(f"Jumlah baris dengan missing value di semua 4 kolom: {len(missing_4_cols)}")
# Out:
# Jumlah baris dengan missing value di semua 4 kolom: 610

# %%
# Drop baris yang memiliki missing value di ke-4 kolom
products_df_cleaned = products_df.dropna(subset=['product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty'], inplace=True)

# %%
# Drop baris yang memiliki missing value di ke-8 kolom
products_df_cleaned = products_df.dropna(subset=['product_category_name',
                                                 'product_name_lenght',
                                                 'product_description_lenght',
                                                 'product_photos_qty',
                                                 'product_weight_g',
                                                 'product_length_cm',
                                                 'product_height_cm',
                                                 'product_width_cm'], inplace=True)

# %%
# Menampilkan informasi detail tentang DataFrame products_df untuk memastikan bahwa sudah tidak ada missing value
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32340 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  float64
#  3   product_description_lenght  32340 non-null  float64
#  4   product_photos_qty          32340 non-null  float64
#  5   product_weight_g            32340 non-null  float64
#  6   product_length_cm           32340 non-null  float64
#  7   product_height_cm           32340 non-null  float64
#  8   product_width_cm            32340 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# > **- Menangani kesalahan tipe data**

# %%
# Mengubah tipe data dari float64 ke int64
products_df['product_photos_qty'] = products_df['product_photos_qty'].astype(int)

# %%
# Menampilkan informasi detail tentang DataFrame products_df untuk memastikan tipe data product_photos_qty sudah berubah
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32340 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  float64
#  3   product_description_lenght  32340 non-null  float64
#  4   product_photos_qty          32340 non-null  int64
#  5   product_weight_g            32340 non-null  float64
#  6   product_length_cm           32340 non-null  float64
#  7   product_height_cm           32340 non-null  float64
#  8   product_width_cm            32340 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# > **- Menangani inaccurate value**

# %%
# Menampilkan baris-baris dari DataFrame 'products_df' yang memiliki nilai 'product_weight_g' sama dengan nilai minimum dari kolom tersebut
products_df[products_df.product_weight_g == products_df.product_weight_g.min()]
# Out:
#                              product_id product_category_name  \
# 9769   81781c0fed9fe1ad6e8c81fca1e1cb08       cama_mesa_banho
# 13683  8038040ee2a71048d4bdbbdc985b69ab       cama_mesa_banho
# 14997  36ba42dd187055e1fbe943b2d11430ca       cama_mesa_banho
# 32079  e673e90efa65a5409ff4196c038bb5af       cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 9769                  51.0                       529.0                   1
# 13683                 48.0                       528.0                   1
# 14997                 53.0                       528.0                   1
# 32079                 53.0                       528.0                   1
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 9769                0.0               30.0               25.0
# 13683               0.0               30.0               25.0
# 14997               0.0               30.0               25.0
# ...

# %%
# Menampilkan semua baris di mana product_category_name adalah 'cama_mesa_banho'
products_df[products_df['product_category_name'] == 'cama_mesa_banho']
# Out:
#                              product_id product_category_name  \
# 10     14aa47b7fe5c25522b47b4b29c98dcb9       cama_mesa_banho
# 19     f53103a77d9cf245e579ea37e5ec51f0       cama_mesa_banho
# 21     518ef5de2c2b3a255e326a4594ba15d9       cama_mesa_banho
# 30     47859fca9dd7485cbd93c3e8993bb74f       cama_mesa_banho
# 42     db46052aed7dff59ba38cf2fe29b87f9       cama_mesa_banho
# ...                                 ...                   ...
# 32916  624a104988a613eba3eae6cd9132d397       cama_mesa_banho
# 32930  5bde14b0ba42a788655c3ebf4ba54597       cama_mesa_banho
# 32940  dfec64aac9b864b2807a7be33222b75f       cama_mesa_banho
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c       cama_mesa_banho
# 32950  106392145fca363410d287a815be6de4       cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 10                    54.0                       630.0                   1
# ...

# %%
# Filter data berdasarkan product_category_name
cama_mesa_banho_df = products_df[products_df['product_category_name'] == 'cama_mesa_banho']

# Hitung mean, median, dan mode dari product_weight_g
mean_weight = cama_mesa_banho_df['product_weight_g'].mean()
median_weight = cama_mesa_banho_df['product_weight_g'].median()
mode_weight = cama_mesa_banho_df['product_weight_g'].mode().values[0]  # mode() mengembalikan Series, ambil nilai pertama

# Tampilkan hasil
print(f"Mean : {mean_weight}")
print(f"Median : {median_weight}")
print(f"Mode : {mode_weight}")
# Out:
# Mean : 2456.4050841862
# Median : 1250.0
# Mode : 600.0

# %%
# Mengganti nilai 'product_weight_g' yang sama dengan 0 untuk kategori produk 'cama_mesa_banho' dengan nilai median_weight
products_df.loc[
    (products_df.product_category_name == 'cama_mesa_banho') &
    (products_df.product_weight_g == 0),
    'product_weight_g'
] = median_weight

# %%
# Menampilkan semua baris di mana product_category_name adalah 'cama_mesa_banho'
products_df[products_df['product_category_name'] == 'cama_mesa_banho']
# Out:
#                              product_id product_category_name  \
# 10     14aa47b7fe5c25522b47b4b29c98dcb9       cama_mesa_banho
# 19     f53103a77d9cf245e579ea37e5ec51f0       cama_mesa_banho
# 21     518ef5de2c2b3a255e326a4594ba15d9       cama_mesa_banho
# 30     47859fca9dd7485cbd93c3e8993bb74f       cama_mesa_banho
# 42     db46052aed7dff59ba38cf2fe29b87f9       cama_mesa_banho
# ...                                 ...                   ...
# 32916  624a104988a613eba3eae6cd9132d397       cama_mesa_banho
# 32930  5bde14b0ba42a788655c3ebf4ba54597       cama_mesa_banho
# 32940  dfec64aac9b864b2807a7be33222b75f       cama_mesa_banho
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c       cama_mesa_banho
# 32950  106392145fca363410d287a815be6de4       cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 10                    54.0                       630.0                   1
# ...

# %%
# Menampilkan baris-baris dari DataFrame 'products_df' yang memiliki nilai 'product_weight_g' sama dengan nilai min untuk memastikan bahwa berat minimum tidak 0 gram
products_df[products_df.product_weight_g == products_df.product_weight_g.min()]
# Out:
#                              product_id product_category_name  \
# 9396   ad7d07f5775feab3f20504d1ad3fff11      moveis_decoracao
# 13397  7ddb76f2c7237acc852358b95e7946a8             papelaria
# 15374  f9fafac43d3416d92ecc303fdeb1743d      moveis_decoracao
# 15675  8aae4df46baf1278422b69edbb50bd35      moveis_decoracao
# 16181  5837bba0ce6e35e6f2dc5c3e223e3276      moveis_decoracao
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 9396                  50.0                      1002.0                   2
# 13397                 49.0                      1048.0                   2
# 15374                 51.0                      1039.0                   2
# 15675                 56.0                      1002.0                   2
# 16181                 52.0                      1041.0                   2
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 9396                2.0               11.0               11.0
# ...

# %% [markdown]
# Terlihat bahwa minimum berat sudah tidak 0 gram lagi

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Pada tahap ini yang dilakukan adalah memperoleh insight dan menjawab pertanyaan analisis dari data yang telah dibersihkan.

# %% [markdown]
# ### Explore Data Customers

# %% [markdown]
#  Dataset ini memuat berbagai informasi terkait customer, seperti customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, dan customer_state.

# %%
# Menampilkan ringkasan statistik untuk semua kolom di dataframe 'customers_df', termasuk statistik deskriptif untuk kolom numerik dan kategorikal
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Berdasarkan rangkuman parameter statistik di atas, diperoleh informasi seperti berikut :
#
# - **customer_id**
#   > Jumlah pelanggan sebanyak 99.441 orang dan setiap pelanggan memiliki customer_id yang unik, maka dari itu frekuensi kemunculan customer_id paling sering adalah 1.
#
# - **customer_unique_id**
#   > Terdapat 99.441 data pelanggan unik berdasarkan customer_unique_id, tetapi jumlah uniknya sedikit lebih rendah yaitu 96.096 yang menunjukkan beberapa ID terkait dengan pelanggan yang sama. ID yang paling sering muncul adalah 8d50f5eadf50201ccdcedfb9e2ac8455 yang menunjukkan bahwa pelanggan ini melakukan transaksi sebanyak 17 kali.
#
# - **customer_zip_code_prefix**
#
#   > Dataset ini mencatat 99.441 kode pos pelanggan dengan rentang yang sangat luas, dari 1.003 hingga 99.990. Kode pos rata-rata 35.137 dengan standar deviasi 29.797 menunjukkan variasi yang signifikan.
#
# - **customer_city**
#
#   > Ada 99.441 data kota pelanggan dengan 4.119 kota unik yang menunjukkan luasnya cakupan geografis. Kota yang paling sering muncul adalah São Paulo dengan 15.540 pelanggan yang menandakan bahwa sebagian besar pelanggan berasal dari kota ini.
#
# - **customer_state**
#   > Dataset ini mencatat 99.441 data provinsi atau wilayah dengan 27 negara bagian unik. Negara bagian yang paling banyak diwakili adalah São Paulo (SP) dengan 41.746 pelanggan yang menunjukkan dominasi dari wilayah ini.

# %%
#  Mengelompokkan data pelanggan berdasarkan kota kemudian mengurutkan hasilnya dari yang terbanyak hingga yang paling sedikit
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Berdasarkan hasil di atas, dapat dilihat bahwa distribusi pelanggan sangat terkonsentrasi di beberapa kota utama. Kota São Paulo memiliki jumlah pelanggan terbanyak dengan 15.540 pelanggan, diikuti oleh Rio de Janeiro dengan 6.882 pelanggan. Kota-kota besar seperti Belo Horizonte dan Brasília juga memiliki jumlah pelanggan yang signifikan, masing-masing dengan 2.773 dan 2.131 pelanggan. Sebaliknya, ada banyak kota dengan jumlah pelanggan yang sangat kecil, bahkan ada kota-kota seperti Ibiara, Rio Espera, Rio dos Indios, Rio dos Cedros, dan Lagoão yang hanya memiliki satu pelanggan masing-masing.

# %%
#  Mengelompokkan data pelanggan berdasarkan negara bagian kemudian mengurutkan hasilnya dari yang terbanyak hingga yang paling sedikit
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# Berdasarkan hasil di atas, distribusi pelanggan terlihat tidak merata antar negara bagian. Negara bagian São Paulo (SP) adalah yang paling banyak memiliki pelanggan, dengan total 41.746 pelanggan, jauh lebih tinggi dibandingkan negara bagian lainnya. Diikuti oleh Rio de Janeiro (RJ) dengan 12.852 pelanggan dan Minas Gerais (MG) dengan 11.635 pelanggan. Negara bagian seperti Rio Grande do Sul (RS) dan Paraná (PR) juga memiliki jumlah pelanggan yang signifikan, masing-masing dengan 5.466 dan 5.045 pelanggan. Sebaliknya, beberapa negara bagian memiliki jumlah pelanggan yang jauh lebih sedikit, seperti Acre (AC) dengan 81 pelanggan dan Amapá (AP) dengan 68 pelanggan. Distribusi pelanggan yang tidak merata ini menunjukkan bahwa sebagian besar pelanggan terkonsentrasi di beberapa negara bagian utama, sementara negara bagian lainnya memiliki kontribusi yang lebih kecil.

# %% [markdown]
# ### Explore Data Orders

# %%
# Menampilkan ringkasan statistik untuk semua kolom di dataframe 'orders_df', termasuk statistik deskriptif untuk kolom numerik dan kategorikal
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              96461                             96461
# unique                             96461                             96461
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         96461                          96461
# ...

# %% [markdown]
# Berdasarkan rangkuman parameter statistik di atas, diperoleh informasi seperti berikut :
#
# - **order_id**
# > Jumlah data pesanan adalah 96.461 dan setiap pesanan memiliki order_id yang unik yang menunjukkan bahwa frekuensi kemunculannya paling sering adalah 1 (hanya muncul sekali).
#
# - **customer_id**
# > Terdapat 96.461 data customer_id dan semua customer_id adalah unik. Frekuensi kemunculan customer_id paling sering adalah 1 menandakan setiap pelanggan hanya memiliki satu ID.
#
# - **order_status**
# > Status pesanan terbagi menjadi dua kategori: "delivered" dan satu kategori lainnya yang tidak disebutkan dalam deskripsi. Kategori "delivered" muncul sebanyak 96.455 kali yang menunjukkan bahwa sebagian besar pesanan telah berhasil dikirimkan.
#
# - **order_purchase_timestamp**
# > Tanggal dan waktu pembelian pesanan berkisar dari 15 September 2016 hingga 29 Agustus 2018. Rata-rata pembelian terjadi pada 1 Januari 2018. Data ini menunjukkan bahwa dataset mencakup periode yang cukup panjang dengan variasi waktu yang signifikan.
#
# - **order_approved_at**
# > Tanggal dan waktu persetujuan pesanan berkisar dari 15 September 2016 hingga 29 Agustus 2018, dengan rata-rata pada 2 Januari 2018. Waktu persetujuan ini mengikuti pola yang sama dengan waktu pembelian.
#
# - **order_delivered_carrier_date**
# > Tanggal dan waktu pengiriman carrier berkisar dari 8 Oktober 2016 hingga 11 September 2018, dengan rata-rata pada 5 Januari 2018. Data ini menunjukkan tanggal pengiriman yang bervariasi dengan waktu pengiriman yang hampir konsisten dengan tanggal persetujuan.
#
# - **order_delivered_customer_date**
# > Tanggal dan waktu pengiriman kepada pelanggan berkisar dari 11 Oktober 2016 hingga 17 Oktober 2018, dengan rata-rata pada 14 Januari 2018. Data ini menunjukkan bahwa pengiriman kepada pelanggan bervariasi namun cenderung terjadi setelah tanggal pengiriman carrier.
#
# - **order_estimated_delivery_date**
# > Tanggal estimasi pengiriman berkisar dari 4 Oktober 2016 hingga 25 Oktober 2018, dengan rata-rata pada 25 Januari 2018. Estimasi pengiriman ini mencerminkan rentang waktu yang diperkirakan untuk pengiriman pesanan sampai ke pelanggan.

# %% [markdown]
# ### Explore Order Items

# %%
# Menampilkan ringkasan statistik untuk semua kolom di dataframe 'order_items_df', termasuk statistik deskriptif untuk kolom numerik dan kategorikal
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# Berdasarkan rangkuman parameter statistik di atas, diperoleh informasi seperti berikut :
#
# - **order_id**
# > Jumlah data pesanan adalah 112.650 dan terdapat 98.666 order_id unik. Order_id yang paling sering muncul adalah `8272b63d03f5f79c56e9e4120aec44ef`yang muncul sebanyak 21 kali yang menunjukkan adanya pesanan berulang dengan ID yang sama.
#
# - **order_item_id**
# > Ada 112.650 item pesanan dengan ID item bervariasi dari 1 hingga 21. Rata-rata ID item adalah 1.197834. Hal ini menunjukkan banyak item memiliki ID yang sangat kecil yang umumnya merupakan ID pertama dari setiap pesanan.
#
# - **product_id**
# > Terdapat 32.951 ID produk unik yang muncul dalam data. Produk dengan ID paling sering muncul adalah `aca2eb7d00ea1a7b8ebd4e68314663af`, muncul sebanyak 527 kali yang menunjukkan produk ini paling sering dipesan.
#
# - **seller_id**
# > Ada 3.095 ID penjual unik dengan frekuensi ID penjual yang paling sering muncul adalah `6560211a19b47992c3666cc44a7e94c0` yang muncul sebanyak 2.033 kali. Hal ini menunjukkan penjual itu memiliki volume penjualan yang tinggi.
#
# - **shipping_limit_date**
# > Tanggal batas pengiriman berkisar dari 19 September 2016 hingga 9 April 2020, dengan rata-rata pada 7 Januari 2018. Data ini menunjukkan rentang waktu pengiriman yang luas dan variasi yang signifikan dalam tanggal batas pengiriman.
#
# - **price**
# > Harga produk berkisar dari 0.85 hingga 6.735, dengan rata-rata harga sebesar 120.65. Data ini menunjukkan variasi harga yang luas, dengan sebagian besar harga berada dalam rentang yang lebih rendah.
#
# - **freight_value**
# > Nilai pengiriman berkisar dari 0 hingga 409.68, dengan rata-rata 19.99 dan standar deviasi 15.81. Hal ini menunjukkan variasi yang signifikan dalam biaya pengiriman, serta sebagian besar nilai pengiriman berada pada tingkat yang lebih rendah.

# %% [markdown]
# ### Explore Products

# %%
# Menampilkan ringkasan statistik untuk semua kolom di dataframe 'products_df', termasuk statistik deskriptif untuk kolom numerik dan kategorikal
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32340                 32340
# unique                             32340                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32340.000000                32340.000000        32340.000000
# ...

# %% [markdown]
# Berdasarkan rangkuman parameter statistik di atas, diperoleh informasi seperti berikut :
#
# - **product_id**
# > Dataset ini mencatat 32.340 ID produk dengan masing-masing ID unik. ID produk yang paling sering muncul frekuensi kemunculannya sebanyak 1 kali yang menunjukkan tidak ada pengulangan ID produk yang signifikan.
#
# - **product_category_name**
# > Terdapat 73 kategori produk yang berbeda. Kategori produk yang paling sering muncul adalah `cama_mesa_banho`, dengan frekuensi 3.029 yang menunjukkan bahwa kategori ini sangat umum dalam dataset.
#
# - **product_name_lenght**
# > Panjang nama produk berkisar dari 5 hingga 76 karakter, dengan rata-rata panjang nama 48.48 karakter. Data ini menunjukkan variasi yang cukup besar dalam panjang nama produk.
#
# - **product_description_lenght**
# > Panjang deskripsi produk berkisar dari 4 hingga 3.992 karakter, dengan rata-rata 771.49 karakter. Ini menunjukkan bahwa beberapa produk memiliki deskripsi yang sangat panjang, sementara yang lain lebih singkat.
#
# - **product_photos_qty**
# > Jumlah foto produk berkisar dari 1 hingga 20, dengan rata-rata 2.19 foto per produk. Data ini menunjukkan bahwa sebagian besar produk memiliki sedikit foto.
#
# - **product_weight_g**
# > Berat produk berkisar dari 2 gram hingga 40.425 gram, dengan rata-rata 2.277 gram. Ada variasi yang signifikan dalam berat produk, namun sebagian besar produk memiliki berat yang lebih ringan.
#
# - **product_length_cm**
# > Panjang produk berkisar dari 7 cm hingga 105 cm, dengan rata-rata 30.85 cm. Data ini menunjukkan variasi dalam ukuran panjang produk.
#
# - **product_height_cm**
# > Tinggi produk berkisar dari 2 cm hingga 105 cm, dengan rata-rata 16.96 cm. Ada variasi yang signifikan dalam tinggi produk, namun banyak produk memiliki tinggi yang relatif rendah.
#
# - **product_width_cm**
# > Lebar produk berkisar dari 6 cm hingga 118 cm, dengan rata-rata 23.21 cm. Data ini menunjukkan variasi dalam ukuran lebar produk, namun sebagian besar produk memiliki lebar yang lebih kecil.

# %% [markdown]
# ### Explore Data Customer dan Orders

# %% [markdown]
# Pada tahap ini dilakukan eksplorasi data pada dataset customers dan orders untuk mengetahui pola pembelian berdasarkan lokasi kota dan negara bagian pelanggan.

# %% [markdown]
# Pertama-tama yang dilakukan adalah mengidentifikasi status pelanggan, apakah seorang pelanggan pernah melakukan order atau tidak. Maka dari itu, dibuatlah sebuah kolom baru bernama “status” pada data customers_df yang memiliki nilai **“Active”** untuk pelanggan yang pernah melakukan order setidaknya sekali dan sebaliknya bernilai **“Non Active”** untuk pelanggan yang belum pernah melakukan order sama sekali.

# %%
# Mengambil daftar customer_id dari orders_df dan menyimpannya dalam list
customer_id_in_orders_df =  orders_df.customer_id.tolist()

# Menambahkan kolom baru 'status' pada customers_df
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")

# Menampilkan 5 sampel acak
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 97915  d8a0e0a95a125e99270837c560431d9d  9bdeb44994c8a469d0555497fd70c3d5
# 74337  4e01a32f9dc37358cf6abbb15917a96c  b9b827b003be252370d4f851f603b58d
# 84880  0281f03348b06722b7e0f92455daafd4  926c047356935ed05cb3fbee9ebcac0b
# 49958  cabbefcde0d172ce74bc7fd88aea6664  1a73dd8155368497280c8bdcd680c9ad
# 87387  601d08f998f53b809794de3a130bedd1  c2c7dcb7ebba7a5e67b6e332f8ed646f
#
#        customer_zip_code_prefix       customer_city customer_state      status
# 97915                      5842           sao paulo             SP      Active
# 74337                     88160             biguacu             SC      Active
# 84880                     88330  balneario camboriu             SC  Non Active
# 49958                     25015     duque de caxias             RJ      Active
# 87387                      7713            caieiras             SP      Active

# %%
# Menghitung jumlah pelanggan berdasarkan status
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        96461
# Non Active     2980
# Name: customer_id, dtype: int64

# %% [markdown]
# Dari tabel tersebut terlihat bahwa dari 99.441 pelanggan, jumlah pelanggan yang "Active" sebanyak 96.461 dan yang "Non Active" sebanyak 2.980. Dari data ini, terlihat bahwa persentase pelanggan yang "Active" adalah sekitar 97%, sementara persentase pelanggan yang "Non Active" adalah sekitar 3%. Hal ini menunjukkan bahwa sebagian besar pelanggan telah melakukan pemesanan, sedangkan hanya sedikit pelanggan yang belum aktif. Ini menandakan bahwa strategi pemasaran dan program loyalitas yang diterapkan cenderung efektif dalam menarik pelanggan untuk melakukan transaksi.

# %%
# Menggabungkan data orders_df dan customers_df berdasarkan 'customer_id' menggunakan metode left join
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# - **JUMLAH ORDER BERDASARKAN KOTA**

# %%
# Mengelompokkan berdasarkan kota, lalu mengurutkan dari yang terbanyak, dan menampilkan 10 kota teratas
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  order_id
# 0              sao paulo     15044
# 1         rio de janeiro      6603
# 2         belo horizonte      2697
# 3               brasilia      2071
# 4               curitiba      1489
# 5               campinas      1406
# 6           porto alegre      1341
# 7               salvador      1188
# 8              guarulhos      1143
# 9  sao bernardo do campo       911

# %% [markdown]
# Berdasarkan hasil tersebut, diketahui bahwa kota Sao Paulo, Rio De Janeiro, dan Belo Horizonte merupakan tiga kota yang memiliki jumlah order terbanyak.

# %% [markdown]
# - **JUMLAH ORDER BERDASARKAN NEGARA BAGIAN**

# %%
# Mengelompokkan berdasarkan negara bagian, lalu mengurutkan dari yang terbanyak, dan menampilkan 10 negara bagian teratas
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#   customer_state  order_id
# 0             SP     40489
# 1             RJ     12351
# 2             MG     11352
# 3             RS      5342
# 4             PR      4923
# 5             SC      3547
# 6             BA      3256
# 7             DF      2080
# 8             ES      1995
# 9             GO      1957

# %% [markdown]
# Berdasarkan hasil tersebut, diketahui bahwa negara bagian Sao Paulo (SP), Rio De Janeiro (RJ), dan Minas Gerais (MG) merupakan tiga negara bagian yang memiliki jumlah order terbanyak.

# %% [markdown]
# ### Explore Data Orders dan Order Items

# %%
# Menggabungkan orders_df dan order_items_df berdasarkan order_id

orders_order_items_df = pd.merge(
    left=orders_df,
    right=order_items_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_order_items_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# DataFrame ini menggabungkan informasi pesanan dengan detail item yang dibeli dalam setiap pesanan.

# %% [markdown]
# ### Explore Data Products dan Order - Order Items

# %%
# Menggabungkan orders_order_items_df dan products_df berdasarkan product_id
sales_product_df = pd.merge(
    left=orders_order_items_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_product_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# DataFrame ini menggabungkan informasi produk dengan detail pesanan dan item yang memungkinkan untuk dilakukannya analisis penjualan berdasarkan kategori produk, harga, dan deskripsi produk.

# %% [markdown]
# **ANALISA PENJUALAN BERDASARKAN TANGGAL**

# %%
total_sales = sales_product_df['order_id'].nunique()
print(f"Jumlah total penjualan: {total_sales}")
# Out:
# Jumlah total penjualan: 96461

# %%
# Mengubah kolom order_purchase_timestamp menjadi format tanggal
sales_product_df['order_purchase_timestamp'] = pd.to_datetime(sales_product_df['order_purchase_timestamp'])

# Mengelompokkan berdasarkan bulan dan tahun, serta menghitung total penjualan
monthly_sales = sales_product_df.groupby(sales_product_df['order_purchase_timestamp'].dt.to_period('M')).agg({
    'price': 'sum',
    'order_id': 'nunique'
}).reset_index()

monthly_sales.head()
# Out:
#   order_purchase_timestamp      price  order_id
# 0                  2016-09     134.97         1
# 1                  2016-10   40941.30       270
# 2                  2016-12      10.90         1
# 3                  2017-01  111712.47       748
# 4                  2017-02  232638.86      1641

# %% [markdown]
# **IDENTIFIKASI PRODUK TERLARIS**

# %%
# Mengelompokkan data berdasarkan product_category_name untuk menghitung jumlah penjualan dan total pendapatan
product_sales_summary = sales_product_df.groupby('product_category_name').agg({
    'order_item_id': 'count',
    'price': 'sum'
}).rename(columns={'order_item_id': 'quantity_sold', 'price': 'total_revenue'}).sort_values(by='total_revenue', ascending=False)

product_sales_summary.head()
# Out:
#                         quantity_sold  total_revenue
# product_category_name
# beleza_saude                     9467     1233211.61
# relogios_presentes               5857     1165898.98
# cama_mesa_banho                 10952     1023300.77
# esporte_lazer                    8429      954626.07
# informatica_acessorios           7643      888613.62

# %% [markdown]
# **ANALISA RATA-RATA NILAI PESANAN**

# %%
# Menghitung total harga per pesanan
order_total_df = sales_product_df.groupby('order_id').agg({
    'price': 'sum'
}).rename(columns={'price': 'order_total'})

# Menghitung rata-rata nilai pesanan
average_order_value = order_total_df['order_total'].mean()
average_order_value
# Out:
# 137.04031349457293

# %%
# Menggabungkan sales_product_df dengan customers_df
all_data_df = pd.merge(
    left=sales_product_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
all_data_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# Pada tahap ini, dilakukan visualisasi data dan explanatory analysis untuk menggali wawasan lebih dalam dari dataset. Visualisasi membantu dalam memahami distribusi data, hubungan antar variabel, dan pola yang mungkin tidak terlihat dalam analisis numerik saja. Grafik dan plot yang dihasilkan digunakan untuk menggambarkan temuan penting dan mendukung keputusan berbasis data dengan memberikan gambaran yang lebih jelas dan intuitif tentang informasi yang ada.

# %% [markdown]
# ### Pertanyaan 1: Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?

# %%
# Mengubah kolom order_purchase_timestamp menjadi format datetime
all_data_df['order_purchase_timestamp'] = pd.to_datetime(all_data_df['order_purchase_timestamp'])

# Melakukan resampling data menjadi bulanan dan menghitung jumlah order dan total revenue
monthly_sales_df = all_data_df.resample(rule='M', on='order_purchase_timestamp').agg({
    'order_id': 'nunique',   # Menghitung jumlah unik order per bulan
    'price': 'sum'           # Menghitung total revenue (berdasarkan kolom price)
})

# Mengubah index menjadi string dengan format 'YYYY-MM' untuk memudahkan pembacaan
monthly_sales_df.index = monthly_sales_df.index.strftime('%Y-%m')

# Mereset index agar lebih mudah diolah
monthly_sales_df = monthly_sales_df.reset_index()

# Mengganti nama kolom agar lebih deskriptif
monthly_sales_df.rename(columns={
    'order_purchase_timestamp': 'month_year',  # Nama kolom waktu
    'order_id': 'order_count',                 # Jumlah pesanan per bulan
    'price': 'revenue'                         # Total revenue per bulan
}, inplace=True)

# Melihat hasil awal
monthly_sales_df.head(10)
# Out:
#   month_year  order_count    revenue
# 0    2016-09            1     134.97
# 1    2016-10          270   40941.30
# 2    2016-11            0       0.00
# 3    2016-12            1      10.90
# 4    2017-01          748  111712.47
# 5    2017-02         1641  232638.86
# 6    2017-03         2546  359198.85
# 7    2017-04         2303  340669.68
# 8    2017-05         3545  489159.25
# 9    2017-06         3135  421923.37

# %%
# Visualisasi jumlah order per bulan
plt.figure(figsize=(10, 5))
plt.plot(monthly_sales_df['month_year'], monthly_sales_df['order_count'], marker='o', linewidth=2, color='#72BCD4')
plt.title('Number of Orders per Month', loc='center', fontsize=20)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Order Count', fontsize=12)
plt.xticks(rotation=45)  # Rotasi label pada sumbu X untuk keterbacaan
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, dapat dilihat bahwa jumlah order terbanyak terjadi pada bulan November 2017. Terjadi kelonjakan jumlah order dari periode Desember 2016 sampai Maret 2017 dan Oktober 2017 sampai November 2017. Namun, terjadi pula penurunan jumlah orderan dan yang paling signifikan adalah pada periode November-Desember 2017.

# %%
# Visualisasi total revenue per bulan
plt.figure(figsize=(10, 5))
plt.plot(monthly_sales_df['month_year'], monthly_sales_df['revenue'], marker='o', linewidth=2, color='#FF6F61')
plt.title('Total Revenue per Month', loc='center', fontsize=20)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Fluktuasi revenue perusahaan kurang lebih sama dengan jumlah order. Penurunan revenue perusahaan paling signifikan adalah saat periode penurunan jumlah order juga yaitu periode November-Desember 2017. Namun, tidak ada penurunan revenue perusahaan yang sangat signifikan.

# %% [markdown]
# **PEMBAHASAN :**
#
# Berdasarkan analisis data, performa penjualan perusahaan menunjukkan adanya pola fluktuasi yang signifikan dalam beberapa bulan terakhir. Jumlah order tertinggi tercatat pada bulan November 2017, menandakan puncak aktivitas pembelian dalam periode tersebut. Selama periode dari Desember 2016 hingga Maret 2017, serta dari Oktober 2017 hingga November 2017, terjadi lonjakan signifikan dalam jumlah order, yang menunjukkan periode penjualan yang sangat produktif. Sebaliknya, terjadi penurunan yang mencolok dalam jumlah order dan revenue pada periode November-Desember 2017. Penurunan ini menunjukkan adanya tantangan dalam mempertahankan konsistensi penjualan. Meskipun demikian, fluktuasi revenue perusahaan mengikuti pola yang mirip dengan jumlah order, tanpa penurunan yang sangat drastis, yang mengindikasikan bahwa penurunan order tidak berdampak secara ekstrem pada revenue.

# %% [markdown]
# ### Pertanyaan 2: Produk apa yang paling banyak dan paling sedikit terjual?

# %%
# Mengelompokkan data berdasarkan nama produk dan menghitung jumlah penjualan
sum_order_items_df = all_data_df.groupby("product_category_name").size().reset_index(name='quantity_sold')

# Mengurutkan DataFrame berdasarkan jumlah penjualan (terbanyak ke sedikit)
sum_order_items_df = sum_order_items_df.sort_values(by='quantity_sold', ascending=False).reset_index(drop=True)

# Menampilkan 15 produk teratas berdasarkan jumlah penjualan
sum_order_items_df.head(15)
# Out:
#      product_category_name  quantity_sold
# 0          cama_mesa_banho          10952
# 1             beleza_saude           9467
# 2            esporte_lazer           8429
# 3         moveis_decoracao           8156
# 4   informatica_acessorios           7643
# 5    utilidades_domesticas           6795
# 6       relogios_presentes           5857
# 7                telefonia           4428
# 8       ferramentas_jardim           4267
# 9               automotivo           4139
# 10              brinquedos           4030
# 11              cool_stuff           3715
# 12              perfumaria           3342
# 13                   bebes           2981
# 14             eletronicos           2729

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="quantity_sold", y="product_category_name",
            data=sum_order_items_df.head(5),
            palette=colors,
            ax=ax[0],
            hue="product_category_name",
            legend=False)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis='y', labelsize=12)

sns.barplot(x="quantity_sold", y="product_category_name",
            data=sum_order_items_df.sort_values(by="quantity_sold", ascending=True).head(5),
            palette=colors,
            ax=ax[1],
            hue="product_category_name",
            legend=False)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# Berdasarkan gambar di atas, dapat dilihat bahwa kategori produk cama mesa banho (kasur, meja, dan handuk - merujuk pada kategori produk untuk kebutuhan rumah tangga) merupakan kategori produk yang paling laris. Kontras dengan hal tersebut, produk seguros e service (asuransi dan layanan) merupakan kategori produk yang paling sedikit terjual.

# %% [markdown]
# **PEMBAHASAN :**
#
# Dari hasil visualisasi data, kategori produk "cama mesa banho" (yang mencakup barang-barang rumah tangga seperti kasur, meja, dan handuk) menonjol sebagai kategori produk dengan penjualan tertinggi. Ini menunjukkan bahwa produk-produk rumah tangga memiliki daya tarik yang kuat dan permintaan yang stabil di pasar. Sebaliknya, kategori produk "seguros e service" (asuransi dan layanan) menunjukkan penjualan yang paling rendah. Hal ini mengindikasikan bahwa produk-produk dalam kategori ini kurang diminati oleh konsumen atau mungkin membutuhkan strategi pemasaran yang lebih efektif untuk meningkatkan penjualannya.

# %% [markdown]
# ### Pertanyaan 3: Bagaimana demografi pelanggan yang melakukan pembelian?

# %%
# Menghitung jumlah pelanggan per negara bagian
bystate_df = all_data_df.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={"customer_id": "customer_count"}, inplace=True)

# Mengatur ukuran gambar
plt.figure(figsize=(12, 8))

# Membuat bar plot tanpa palette khusus
sns.barplot(
    x="customer_count",
    y="customer_state",
    data=bystate_df.sort_values(by="customer_count", ascending=False)
)

# Menambahkan judul dan label
plt.title("Jumlah Pelanggan per Negara Bagian", fontsize=16)
plt.xlabel("Jumlah Pelanggan")
plt.ylabel("Negara Bagian")

# Menampilkan plot
plt.show()

# %% [markdown]
# Berdasarkan visualisasi data tersebut, dapat diketahui bahwa pelanggan yang paling banyak berasal dari negara bagian Sao Paulo (SP).

# %% [markdown]
# **PEMBAHASAN :**
#
# Analisis demografi pelanggan menunjukkan bahwa mayoritas pembeli berasal dari negara bagian Sao Paulo (SP). Ini mencerminkan konsentrasi besar dari basis pelanggan di wilayah ini yang menandakan bahwa Sao Paulo adalah pasar utama bagi perusahaan. Strategi bisnis dan pemasaran yang ditargetkan pada wilayah ini bisa sangat menguntungkan, mengingat potensi besar dari konsumen yang berada di negara bagian ini. Upaya untuk memperluas jangkauan pasar ke wilayah lain atau memperdalam hubungan dengan pelanggan di Sao Paulo dapat menjadi langkah strategis yang berharga untuk meningkatkan performa penjualan.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# **RFM Analysis**

# %% [markdown]
# RFM analysis merupakan salah satu metode yang umum digunakan untuk melakukan segmentasi pelanggan (mengelompokkan pelanggan ke dalam beberapa kategori) berdasarkan tiga parameter, yaitu recency, frequency, dan monetary.
#
# - Recency: parameter yang digunakan untuk melihat kapan terakhir seorang pelanggan melakukan transaksi.
# - Frequency: parameter ini digunakan untuk mengidentifikasi seberapa sering seorang pelanggan melakukan transaksi.
# - Monetary: parameter terakhir ini digunakan untuk mengidentifikasi seberapa besar revenue yang berasal dari pelanggan tersebut.
#
# Berdasarkan tiga parameter tersebut, kita bisa mengidentifikasi pelanggan mana yang memiliki high value (sering melakukan transaksi dan menghasilkan revenue yang besar) dan low value.

# %%
# Pastikan bahwa kolom 'order_purchase_timestamp' adalah datetime
all_data_df['order_purchase_timestamp'] = pd.to_datetime(all_data_df['order_purchase_timestamp'])
# Ambil tanggal terbaru dalam dataset untuk perhitungan recency
recent_date = all_data_df['order_purchase_timestamp'].max()

# Hitung Recency, Frequency, dan Monetary
rfm_df = all_data_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max",  # Mengambil tanggal order terakhir
    "order_id": "nunique",  # Menghitung jumlah order
    "price": "sum"  # Menghitung total revenue yang dihasilkan
})

rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

# Menghitung Recency (hari sejak transaksi terakhir)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date.date() - x).days)

# Menghapus kolom tanggal order terakhir
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)

# Menampilkan DataFrame RFM
rfm_df.head(10)
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      288
# 1  000161a058600d5901f007fab4c27140          1     54.90      409
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      547
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      378
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      149
# 5  0004164d20a9e969af783496f3408652          1     59.99      504
# 6  000419c5494106c306a97b5635748086          1     34.30      180
# 7  00046a560d407e99b969756e0b10f282          1    120.90      254
# 8  00050bf6e01e69d5c0fd612f1bcfb69c          1     69.99      346
# 9  000598caf2ef4117407665ac33275130          1   1107.00       18

# %%
# Mengatur ukuran gambar dan layout menjadi satu kolom dengan tiga baris
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 18))

# Visualisasi berdasarkan Recency
sns.barplot(
    y="customer_id",
    x="recency",
    data=rfm_df.sort_values(by="recency", ascending=True).head(5),
    ax=ax[0]
)
ax[0].set_ylabel(None)
ax[0].set_xlabel("Recency (days)")
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis='x', labelsize=15)
ax[0].tick_params(axis='x', rotation=90)  # Mengatur label x menjadi vertikal

# Visualisasi berdasarkan Frequency
sns.barplot(
    y="customer_id",
    x="frequency",
    data=rfm_df.sort_values(by="frequency", ascending=False).head(5),
    ax=ax[1]
)
ax[1].set_ylabel(None)
ax[1].set_xlabel("Frequency")
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)
ax[1].tick_params(axis='x', rotation=90)  # Mengatur label x menjadi vertikal

# Visualisasi berdasarkan Monetary
sns.barplot(
    y="customer_id",
    x="monetary",
    data=rfm_df.sort_values(by="monetary", ascending=False).head(5),
    ax=ax[2]
)
ax[2].set_ylabel(None)
ax[2].set_xlabel("Monetary")
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)
ax[2].tick_params(axis='x', rotation=90)  # Mengatur label x menjadi vertikal

# Menambahkan judul keseluruhan
plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)

# Menampilkan plot
plt.tight_layout(rect=[0, 0, 1, 0.97])  # Mengatur layout agar tidak saling tumpang tindih
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?
# > Performa penjualan menunjukkan puncak tertinggi pada November 2017, dengan lonjakan pesanan dari Desember 2016 hingga Maret 2017 dan Oktober hingga November 2017. Namun, ada penurunan signifikan pada November-Desember 2017 yang juga berdampak pada revenue. Meski demikian, penurunan revenue tidak sangat drastis.
#
# 2. Produk apa yang paling banyak dan paling sedikit terjual?
# > Produk "cama mesa banho" (barang-barang rumah tangga) adalah yang paling banyak terjual, menunjukkan permintaan yang kuat di kategori ini. Sebaliknya, kategori "seguros e service" (asuransi dan layanan) memiliki penjualan terendah, menunjukkan kurangnya minat konsumen.
#
# 3. Bagaimana demografi pelanggan yang melakukan pembelian?
# > Sebagian besar pelanggan berasal dari negara bagian Sao Paulo (SP) yang menandakan konsentrasi pasar utama di wilayah ini. Strategi pemasaran yang fokus pada Sao Paulo bisa sangat menguntungkan, mengingat potensi besar dari pelanggan di area tersebut.
